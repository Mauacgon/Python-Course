# %%
## I did it like this

import random
suits = ('Hearts','Diamonds','Spades','Clubs')
ranks = ('Two', "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine", "Ten", "Jack", "Queen", "King", "Ace")
values = {'Two':2, "Three":3, "Four":4, "Five":5, "Six":6, "Seven":7, "Eight":8,
        "Nine":9, "Ten":10, "Jack":11, "Queen":12, "King":13, "Ace":14}


class Card():
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[self.rank]     ## Adding self to rank as values[self.rank] is optional, you could write just rank within brackets
        
    def __str__(self):
        return self.rank + " of " + self.suit
    
class Deck():
    
    def __init__(self):
        self.all_cards = []
        
        for i in suits:
            for j in ranks:
                self.all_cards.append(Card(i,j))
                
    def shuffle(self):
        self.shuffled_cards = random.sample(self.all_cards,len(self.all_cards))
        
    def deal_one(self):
        return self.all_cards.pop()
        
class Player():
    
    def __init__(self,iden):
        
        self.iden = iden
        
        self.points = 0  
        self.all_cards = []
        
    def deal_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if len(new_cards) <= 1:
            self.all_cards.append(new_cards)
        else:
            self.all_cards.expand(new_cards)
    def __str__(self):
        return f'player {self.iden} has {len(self.all_cards)} cards'

# %%
##In the course it is done like this

import random
suits = ('Hearts','Diamonds','Spades','Clubs')
ranks = ('Two', "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine", "Ten", "Jack", "Queen", "King", "Ace")
values = {'Two':2, "Three":3, "Four":4, "Five":5, "Six":6, "Seven":7, "Eight":8,
        "Nine":9, "Ten":10, "Jack":11, "Queen":12, "King":13, "Ace":14}
Player_name1 = ""
Player_name2 = ""


class Card():
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[self.rank]     ## Adding self to rank as values[self.rank] is optional, you could write just rank within brackets
        
    def __str__(self):
        return self.rank + " of " + self.suit
    
class Deck():
    
    def __init__(self):
        self.all_cards = []
        
        for i in suits:
            for j in ranks:
                self.all_cards.append(Card(i,j))
                
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()
        
class Player():
    
    def __init__(self,iden):
        
        self.iden = iden
        
        self.points = 0  
        self.all_cards = []
        
    def deal_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
    def __str__(self):
        return f'player {self.iden} has {len(self.all_cards)} cards'
    
def  game():
    
    global Player_name1; global player_name2
    
    Player_name1 = input("Insert player 1 name ____")
    Player_name2 = input("Insert player 2 name ____")

    Player1 = Player(Player_name1)
    Player2 = Player(Player_name2)

    My_Deck = Deck()

    ## Shuffle the Deck

    input("Press some key to shuffle the Deck __")

    My_Deck.shuffle()

    reshuffle = input("Do you want to reshuffle? (Y/N) __")

    while reshuffle != "N":
        if reshuffle != "Y":            
            reshuffle = input("Type Y in case you want to reshuffle, type N in otherwise")
        else:
            My_Deck.shuffle()
            reshuffle = input("Do you want to reshuffle? (Y/N) __")

    input("Deck reshuffled, press any key to go on")

    ## Split the Deck between the players

    Player1.add_cards(My_Deck.all_cards[0:int((len(My_Deck.all_cards)/2))])

    Player2.add_cards(My_Deck.all_cards[int((len(My_Deck.all_cards)/2)):int(len(My_Deck.all_cards))])

    input("Deck has been distributed, press any key to start the game")

    rep = 0

    cardsatstake = []

    ##Start out the game

    while len(Player1.all_cards) != 0 and len(Player1.all_cards) != 0:

        ## Place the first two cards into the table and remove them from every player's stack

        try:
            cardsatstake.append(Player1.all_cards[0])
            cardsatstake.append(Player2.all_cards[0])
            Player1.deal_one()
            Player2.deal_one()
        except:
            break

        for i in range(0,len(cardsatstake)):
            print(cardsatstake[i])

        if cardsatstake[-2].value > cardsatstake[-1].value:
            Player1.add_cards(cardsatstake)
            print(f'{Player1.iden} plays {cardsatstake[-2]}, {Player2.iden} plays {cardsatstake[-1]}')
            print(f'Value of {Player1.iden} is {cardsatstake[-2].value}, value of {Player2.iden} is {cardsatstake[-1].value}')
            print(f'{Player1.iden} wins')
            print(f'{Player1.iden} has {len(Player1.all_cards)} cards left, {Player2.iden} has {len(Player2.all_cards)} cards left')
            cardsatstake = []

        elif cardsatstake[-2].value < cardsatstake[-1].value:
            Player2.add_cards(cardsatstake)
            print(f'{Player1.iden} plays {cardsatstake[-2]}, {Player2.iden} plays {cardsatstake[-1]}')
            print(f'Value of {Player1.iden} is {cardsatstake[-2].value}, value of {Player2.iden} is {cardsatstake[-1].value}')
            print(f'{Player2.iden} wins')
            print(f'{Player1.iden} has {len(Player1.all_cards)} cards left, {Player2.iden} has {len(Player2.all_cards)} cards left')
            cardsatstake = []

        else:
            while cardsatstake[-2].value == cardsatstake[-1].value:
                print(f'{Player1.iden} plays {cardsatstake[-2]}, {Player2.iden} plays {cardsatstake[-1]}')
                print(f'Value of {Player1.iden} is {cardsatstake[-2].value}, value of {Player2.iden} is {cardsatstake[-1].value}')
                try:
                    for i in range(0,3):
                        cardsatstake.append(Player1.all_cards[i])
                        cardsatstake.append(Player2.all_cards[i])
                        Player1.deal_one()
                        Player2.deal_one()
                    print(f'Tie, a war has begun')
                except:
                    break

    try: 
        Player1.all_cards[25]
        print(f'winner is {Player1.iden}')
    except:
        print(f'winner is {Player2.iden}')

# %%
game()
# Out:
# Insert player 1 name ____Mauro
# Insert player 2 name ____Jaime
# Press some key to shuffle the Deck __d
# Do you want to reshuffle? (Y/N) __Y
# Do you want to reshuffle? (Y/N) __Y
# Do you want to reshuffle? (Y/N) __Y
# Do you want to reshuffle? (Y/N) __Y
# Do you want to reshuffle? (Y/N) __Y
# Do you want to reshuffle? (Y/N) __Y
# Do you want to reshuffle? (Y/N) __N
# Deck reshuffled, press any key to go onD
# Deck has been distributed, press any key to start the gameD
# Eight of Hearts
# Ten of Hearts
# Mauro plays Eight of Hearts, Jaime plays Ten of Hearts
# Value of Mauro is 8, value of Jaime is 10
# Jaime wins
# Mauro has 25 cards left, Jaime has 27 cards left
# Three of Clubs
# Three of Hearts
# Mauro plays Three of Clubs, Jaime plays Three of Hearts
# Value of Mauro is 3, value of Jaime is 3
# Tie, a war has begun
# Three of Clubs
# Three of Hearts
# Ten of Clubs
# Queen of Spades
# Two of Hearts
# Five of Diamonds
# Four of Spades
# Five of Hearts
# Three of Diamonds
# ...

# %%
Fprint(new_Deck.all_cards[5])
# Out:
# Seven of Hearts

# %%
new_Deck.all_cards[3].value
# Out:
# 5

# %%
print(two_hearts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c2e5e6111ded> in <module>
# ----> 1 print(two_hearts)
#
# NameError: name 'two_hearts' is not defined

# %%
first_card = new_Deck.all_cards[0]

# %%
first_card.suit
# Out:
# 'Hearts'

# %%
last_card = new_Deck.all_cards[-1]

# %%
print(last_card)
# Out:
# Ace of Clubs

# %%
for card in new_Deck.all_cards:
    print(card)
# Out:
# Two of Hearts
# Three of Hearts
# Four of Hearts
# Five of Hearts
# Six of Hearts
# Seven of Hearts
# Eight of Hearts
# Nine of Hearts
# Ten of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# Two of Diamonds
# Three of Diamonds
# Four of Diamonds
# Five of Diamonds
# Six of Diamonds
# Seven of Diamonds
# Eight of Diamonds
# Nine of Diamonds
# Ten of Diamonds
# Jack of Diamonds
# Queen of Diamonds
# King of Diamonds
# Ace of Diamonds
# Two of Spades
# Three of Spades
# Four of Spades
# Five of Spades
# Six of Spades
# Seven of Spades
# Eight of Spades
# Nine of Spades
# Ten of Spades
# Jack of Spades
# Queen of Spades
# King of Spades
# Ace of Spades
# Two of Clubs
# Three of Clubs
# Four of Clubs
# Five of Clubs
# Six of Clubs
# Seven of Clubs
# Eight of Clubs
# Nine of Clubs
# Ten of Clubs
# Jack of Clubs
# Queen of Clubs
# King of Clubs
# Ace of Clubs

# %%
numbers = [1,2,3,4,5,6]

sample = random.sample(numbers,len(numbers))

# %%
sample
# Out:
# [5, 3, 1, 2, 4, 6]

# %%
new_Deck.shuffle()

# %%
for card in new_Deck.shuffled_cards:
    print(card)
# Out:
# Four of Clubs
# King of Hearts
# Ace of Clubs
# King of Clubs
# Ace of Spades
# Two of Hearts
# Seven of Spades
# Jack of Clubs
# Seven of Diamonds
# Four of Spades
# Two of Spades
# Six of Hearts
# Five of Spades
# Six of Spades
# Six of Clubs
# Nine of Spades
# Ten of Hearts
# Six of Diamonds
# Three of Diamonds
# Jack of Hearts
# Eight of Clubs
# King of Diamonds
# Ten of Spades
# Eight of Hearts
# King of Spades
# Ace of Hearts
# Four of Hearts
# Four of Diamonds
# Jack of Spades
# Queen of Hearts
# Eight of Spades
# Ace of Diamonds
# Ten of Clubs
# Nine of Clubs
# Ten of Diamonds
# Queen of Diamonds
# Five of Diamonds
# Three of Hearts
# Queen of Spades
# Jack of Diamonds
# Three of Spades
# Three of Clubs
# Queen of Clubs
# Seven of Hearts
# Two of Clubs
# Nine of Hearts
# Two of Diamonds
# Seven of Clubs
# Five of Clubs
# Nine of Diamonds
# Five of Hearts
# Eight of Diamonds

# %%
list1 = [1,2,3,4,5,6]

# %%
poppedobj = list1.pop()

# %%
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
New_player = Player("Jose")

# %%
print(New_player)
# Out:
# player Jose has 0 cards

# %%
New_player.add_cards(first_card)

# %%
New_player.all_cards[0]

# %%
print(New_player.all_cards[0])
# Out:
# Two of Hearts

# %%
print(New_player)
# Out:
# player Jose has 1 cards

# %%
New_player.add_cards([first_card,first_card,first_card])

# %%
for card in New_player.all_cards:
    print(card)
# Out:
# Two of Hearts
# Two of Hearts
# Two of Hearts
# Two of Hearts

# %%
print(New_player)
# Out:
# player Jose has 4 cards
